# %%
import pandas as pd 
from sklearn.model_selection import StratifiedKFold

# %%
dataset_path = pd.read_csv('../data_splits/train_path.csv')
dataset_path
# Out:
#       Unnamed: 0                                         image_path  target
# 0            799  /home/sebastien/Documents/projects/solafune-fi...       0
# 1            474  /home/sebastien/Documents/projects/solafune-fi...       0
# 2            395  /home/sebastien/Documents/projects/solafune-fi...       0
# 3            252  /home/sebastien/Documents/projects/solafune-fi...       0
# 4             11  /home/sebastien/Documents/projects/solafune-fi...       0
# ...          ...                                                ...     ...
# 1110          91  /home/sebastien/Documents/projects/solafune-fi...       0
# 1111         904  /home/sebastien/Documents/projects/solafune-fi...       0
# 1112         442  /home/sebastien/Documents/projects/solafune-fi...       0
# 1113         443  /home/sebastien/Documents/projects/solafune-fi...       0
# 1114        1099  /home/sebastien/Documents/projects/solafune-fi...       0
#
# [1115 rows x 3 columns]

# %%
stratified_kfold = StratifiedKFold(n_splits=10)

# %%
stratified_kfold
# Out:
# StratifiedKFold(n_splits=10, random_state=None, shuffle=False)

# %%
for fold, (train_indices, val_indices) in enumerate(stratified_kfold.split(dataset_path.image_path, dataset_path.target)):
    print(f"Fold {fold}:")

    fold_df_train = dataset_path.iloc[train_indices]
    fold_df_val = dataset_path.iloc[val_indices]
    fold_df_train.to_csv("train_" + str(fold)+".csv")
    fold_df_val.to_csv("val_" + str(fold)+".csv")
# Out:
# Fold 0:
# Fold 1:
# Fold 2:
# Fold 3:
# Fold 4:
# Fold 5:
# Fold 6:
# Fold 7:
# Fold 8:
# Fold 9:

# %%
pd.read_csv('train_0.csv')
# Out:
#       Unnamed: 0.1  Unnamed: 0  \
# 0              102         946
# 1              103         842
# 2              105         200
# 3              106        1169
# 4              107         327
# ...            ...         ...
# 998           1110          91
# 999           1111         904
# 1000          1112         442
# 1001          1113         443
# 1002          1114        1099
#
#                                              image_path  target
# 0     /home/sebastien/Documents/projects/solafune-fi...       0
# 1     /home/sebastien/Documents/projects/solafune-fi...       0
# 2     /home/sebastien/Documents/projects/solafune-fi...       0
# 3     /home/sebastien/Documents/projects/solafune-fi...       0
# 4     /home/sebastien/Documents/projects/solafune-fi...       0
# ...                                                 ...     ...
# 998   /home/sebastien/Documents/projects/solafune-fi...       0
# 999   /home/sebastien/Documents/projects/solafune-fi...       0
# 1000  /home/sebastien/Documents/projects/solafune-fi...       0
# 1001  /home/sebastien/Documents/projects/solafune-fi...       0
# 1002  /home/sebastien/Documents/projects/solafune-fi...       0
#
# [1003 rows x 4 columns]

# %%
pd.read_csv('train_9.csv')
# Out:
#       Unnamed: 0.1  Unnamed: 0  \
# 0                0         799
# 1                1         474
# 2                2         395
# 3                3         252
# 4                4          11
# ...            ...         ...
# 999           1000         566
# 1000          1001         651
# 1001          1002         304
# 1002          1003         378
# 1003          1004         629
#
#                                              image_path  target
# 0     /home/sebastien/Documents/projects/solafune-fi...       0
# 1     /home/sebastien/Documents/projects/solafune-fi...       0
# 2     /home/sebastien/Documents/projects/solafune-fi...       0
# 3     /home/sebastien/Documents/projects/solafune-fi...       0
# 4     /home/sebastien/Documents/projects/solafune-fi...       0
# ...                                                 ...     ...
# 999   /home/sebastien/Documents/projects/solafune-fi...       0
# 1000  /home/sebastien/Documents/projects/solafune-fi...       0
# 1001  /home/sebastien/Documents/projects/solafune-fi...       0
# 1002  /home/sebastien/Documents/projects/solafune-fi...       0
# 1003  /home/sebastien/Documents/projects/solafune-fi...       0
#
# [1004 rows x 4 columns]

# %%
pd.read_csv('train_4.csv')
# Out:
#       Unnamed: 0.1  Unnamed: 0  \
# 0                0         799
# 1                1         474
# 2                2         395
# 3                3         252
# 4                4          11
# ...            ...         ...
# 998           1110          91
# 999           1111         904
# 1000          1112         442
# 1001          1113         443
# 1002          1114        1099
#
#                                              image_path  target
# 0     /home/sebastien/Documents/projects/solafune-fi...       0
# 1     /home/sebastien/Documents/projects/solafune-fi...       0
# 2     /home/sebastien/Documents/projects/solafune-fi...       0
# 3     /home/sebastien/Documents/projects/solafune-fi...       0
# 4     /home/sebastien/Documents/projects/solafune-fi...       0
# ...                                                 ...     ...
# 998   /home/sebastien/Documents/projects/solafune-fi...       0
# 999   /home/sebastien/Documents/projects/solafune-fi...       0
# 1000  /home/sebastien/Documents/projects/solafune-fi...       0
# 1001  /home/sebastien/Documents/projects/solafune-fi...       0
# 1002  /home/sebastien/Documents/projects/solafune-fi...       0
#
# [1003 rows x 4 columns]
